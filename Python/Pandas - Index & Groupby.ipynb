# %% [markdown]
# # Pandas - Index & Groupby

# %%
import numpy as np
import pandas as pd

# %%
data = {'color': ['black', 'white', 'black', 'white', 'black', 'white', 'black', 'white', 'black', 'white'],
        'size': ['S', 'M', 'L', 'M', 'L', 'S', 'S', 'XL', 'XL', 'M'],
        'data': pd.date_range('1/1/2019', periods=10, freq='W'),
        'a': np.random.randn(10),
        'b': np.random.normal(0.5, 2, 10)}

index = [['A', 'B', 'B', 'B', 'C', 'A', 'B', 'A', 'C', 'C'], ['JP', 'CN', 'US', 'US', 'US', 'CN', 'CN', 'CA', 'JP', 'CA']]
index = pd.MultiIndex.from_arrays(index, names=['class', 'country'])

# %%
df = pd.DataFrame(data, index=index)
df
# Out:
#                color size       data         a         b
# class country
# A     JP       black    S 2019-01-06  1.504432  0.243258
# B     CN       white    M 2019-01-13 -0.126859  3.785009
#       US       black    L 2019-01-20 -1.203678  0.023889
#       US       white    M 2019-01-27 -0.144241  3.149552
# C     US       black    L 2019-02-03 -0.385681 -0.641574
# A     CN       white    S 2019-02-10  1.250439 -0.607894
# B     CN       black    S 2019-02-17  0.087329 -2.457463
# A     CA       white   XL 2019-02-24 -1.102457  0.097761
# C     JP       black   XL 2019-03-03 -1.173527  1.404316
#       CA       white    M 2019-03-10  2.812170 -0.078980

# %%
df2 = pd.DataFrame(data)
df2.append({'color': 'green', 'size': 'XS', 'data': '2019-02-01 00:00:00', 'a': 1, 'b': -3}, ignore_index=True)
# Out:
#     color size                 data         a         b
# 0   black    S  2019-01-06 00:00:00  3.379347 -1.720918
# 1   white    M  2019-01-13 00:00:00  1.085067 -1.771311
# 2   black    L  2019-01-20 00:00:00 -0.784112 -1.842510
# 3   white    M  2019-01-27 00:00:00  1.789608  0.789167
# 4   black    L  2019-02-03 00:00:00  0.229144 -1.256342
# 5   white    S  2019-02-10 00:00:00 -0.257723  3.844117
# 6   black    S  2019-02-17 00:00:00 -2.262585  4.732390
# 7   white   XL  2019-02-24 00:00:00 -0.835432 -1.177477
# 8   black   XL  2019-03-03 00:00:00  0.367152 -0.356291
# 9   white    M  2019-03-10 00:00:00 -0.693315  3.003024
# 10  green   XS  2019-02-01 00:00:00  1.000000 -3.000000

# %%
# more efficent
dic = dict({'color': ['green'], 'size': ['XS'], 'data': ['2019-02-01 00:00:00'], 'a': [1], 'b': [-3]})

pd.concat([df2, pd.DataFrame(dic)], ignore_index=True)
# Out:
#     color size                 data         a         b
# 0   black    S  2019-01-06 00:00:00  3.379347 -1.720918
# 1   white    M  2019-01-13 00:00:00  1.085067 -1.771311
# 2   black    L  2019-01-20 00:00:00 -0.784112 -1.842510
# 3   white    M  2019-01-27 00:00:00  1.789608  0.789167
# 4   black    L  2019-02-03 00:00:00  0.229144 -1.256342
# 5   white    S  2019-02-10 00:00:00 -0.257723  3.844117
# 6   black    S  2019-02-17 00:00:00 -2.262585  4.732390
# 7   white   XL  2019-02-24 00:00:00 -0.835432 -1.177477
# 8   black   XL  2019-03-03 00:00:00  0.367152 -0.356291
# 9   white    M  2019-03-10 00:00:00 -0.693315  3.003024
# 10  green   XS  2019-02-01 00:00:00  1.000000 -3.000000

# %% [markdown]
# ### group by specific columns

# %%
size_lvl = df.groupby('size')

for i in size_lvl:
    print(i)
# Out:
# ('L',                color size       data         a         b
# class country
# B     US       black    L 2019-01-20 -1.203678  0.023889
# C     US       black    L 2019-02-03 -0.385681 -0.641574)
# ('M',                color size       data         a         b
# class country
# B     CN       white    M 2019-01-13 -0.126859  3.785009
#       US       white    M 2019-01-27 -0.144241  3.149552
# C     CA       white    M 2019-03-10  2.812170 -0.078980)
# ('S',                color size       data         a         b
# class country
# A     JP       black    S 2019-01-06  1.504432  0.243258
#       CN       white    S 2019-02-10  1.250439 -0.607894
# B     CN       black    S 2019-02-17  0.087329 -2.457463)
# ('XL',                color size       data         a         b
# class country
# A     CA       white   XL 2019-02-24 -1.102457  0.097761
# C     JP       black   XL 2019-03-03 -1.173527  1.404316)

# %% [markdown]
# ### select specific group

# %%
size_lvl.get_group('M')
# Out:
#                color       data         a         b
# class country
# B     CN       white 2019-01-13  0.403105 -0.061578
#       US       white 2019-01-27 -0.950894 -1.255788
# C     CA       white 2019-03-10  0.997361  1.465797

# %%
# 0: class, 1: country
for i in list(df.groupby(level=[0,1])):
    print(i)
# Out:
# (('A', 'CA'),                color size       data         a         b
# class country
# A     CA       white   XL 2019-02-24  0.389593  4.642428)
# (('A', 'CN'),                color size       data         a         b
# class country
# A     CN       white    S 2019-02-10 -0.198026 -2.008272)
# (('A', 'JP'),                color size       data         a         b
# class country
# A     JP       black    S 2019-01-06 -0.350326  3.920069)
# (('B', 'CN'),                color size       data         a         b
# class country
# B     CN       white    M 2019-01-13  0.403105 -0.061578
#       CN       black    S 2019-02-17  0.519806  1.000723)
# (('B', 'US'),                color size       data         a         b
# class country
# B     US       black    L 2019-01-20 -1.782448  1.430286
#       US       white    M 2019-01-27 -0.950894 -1.255788)
# (('C', 'CA'),                color size       data         a         b
# class country
# C     CA       white    M 2019-03-10  0.997361  1.465797)
# (('C', 'JP'),                color size       data         a         b
# class country
# C     JP       black   XL 2019-03-03 -0.567004  2.649234)
# (('C', 'US'),                color size       data         a        b
# class country
# C     US       black    L 2019-02-03  0.979349  0.55671)

# %% [markdown]
# ## Aggregation

# %%
size_lvl.sum().add_prefix('sum_')
# Out:
#          sum_a     sum_b
# size
# L    -1.589359 -0.617685
# M     2.541069  6.855581
# S     2.842200 -2.822100
# XL   -2.275984  1.502077

# %%
df.groupby('size')['a', 'b'].agg(['sum'])
# Out:
#              a         b
#            sum       sum
# size
# L    -1.589359 -0.617685
# M     2.541069  6.855581
# S     2.842200 -2.822100
# XL   -2.275984  1.502077

# %%
df.groupby(['size', 'color']).agg({'a': np.min, 'b': np.mean})
# Out:
#                    a         b
# size color
# L    black -1.203678 -0.308842
# M    white -0.144241  2.285194
# S    black  0.087329 -1.107103
#      white  1.250439 -0.607894
# XL   black -1.173527  1.404316
#      white -1.102457  0.097761

# %% [markdown]
# ### apply customize function

# %%
data_range = lambda x: x.max() - x.min()
df.groupby('size').transform(data_range)
# Out:
#                  data         a         b
# class country
# A     JP      42 days  0.870131  5.928341
# B     CN      56 days  1.948255  2.721586
#       US      14 days  2.761798  0.873576
#       US      56 days  1.948255  2.721586
# C     US      14 days  2.761798  0.873576
# A     CN      42 days  0.870131  5.928341
# B     CN      42 days  0.870131  5.928341
# A     CA       7 days  0.956596  1.993194
# C     JP       7 days  0.956596  1.993194
#       CA      56 days  1.948255  2.721586

# %%
df.iloc[1, 3:5] = np.NaN
df
# Out:
#                color size       data         a         b
# class country
# A     JP       black    S 2019-01-06 -0.350326  3.920069
# B     CN       white    M 2019-01-13       NaN       NaN
#       US       black    L 2019-01-20 -1.782448  1.430286
#       US       white    M 2019-01-27 -0.950894 -1.255788
# C     US       black    L 2019-02-03  0.979349  0.556710
# A     CN       white    S 2019-02-10 -0.198026 -2.008272
# B     CN       black    S 2019-02-17  0.519806  1.000723
# A     CA       white   XL 2019-02-24  0.389593  4.642428
# C     JP       black   XL 2019-03-03 -0.567004  2.649234
#       CA       white    M 2019-03-10  0.997361  1.465797

# %%
f = lambda x: x.fillna(x.mean())
df = df.groupby(['class', 'country']).transform(f)
df
# Out:
#                       a         b
# class country
# A     JP      -0.350326  3.920069
# B     CN       0.519806  1.000723
#       US      -1.782448  1.430286
#       US      -0.950894 -1.255788
# C     US       0.979349  0.556710
# A     CN      -0.198026 -2.008272
# B     CN       0.519806  1.000723
# A     CA       0.389593  4.642428
# C     JP      -0.567004  2.649234
#       CA       0.997361  1.465797

# %%
for i in df.groupby('color'):
    print(i)
# Out:
# ('black',                color size       data         a         b
# class country
# A     JP       black    S 2019-01-06 -0.350326  3.920069
# B     US       black    L 2019-01-20 -1.782448  1.430286
# C     US       black    L 2019-02-03  0.979349  0.556710
# B     CN       black    S 2019-02-17  0.519806  1.000723
# C     JP       black   XL 2019-03-03 -0.567004  2.649234)
# ('white',                color size       data         a         b
# class country
# B     CN       white    M 2019-01-13       NaN       NaN
#       US       white    M 2019-01-27 -0.950894 -1.255788
# A     CN       white    S 2019-02-10 -0.198026 -2.008272
#       CA       white   XL 2019-02-24  0.389593  4.642428
# C     CA       white    M 2019-03-10  0.997361  1.465797)

# %% [markdown]
# ## Rolling

# %%
df.groupby('color').rolling(3).a.sum()
# Out:
# color  class  country
# black  A      JP              NaN
#        B      US              NaN
#        C      US        -1.153425
#        B      CN        -0.283293
#        C      JP         0.932151
# white  B      CN              NaN
#               US              NaN
#        A      CN              NaN
#               CA        -0.759327
#        C      CA         1.188928
# Name: a, dtype: float64

# %% [markdown]
# ## Expanding

# %%
df.groupby('color').expanding(3).a.sum()
# Out:
# color  class  country
# black  A      JP              NaN
#        B      US              NaN
#        C      US        -1.153425
#        B      CN        -0.633619
#        C      JP        -1.200623
# white  B      CN              NaN
#               US              NaN
#        A      CN              NaN
#               CA        -0.759327
#        C      CA         0.238034
# Name: a, dtype: float64

# %% [markdown]
# ## Filter

# %%
df.groupby('class').filter(lambda x: len(x) > 3)
# Out:
#                color size       data         a         b
# class country
# B     CN       white    M 2019-01-13       NaN       NaN
#       US       black    L 2019-01-20 -1.782448  1.430286
#       US       white    M 2019-01-27 -0.950894 -1.255788
#       CN       black    S 2019-02-17  0.519806  1.000723

# %% [markdown]
# ## Apply

# %%
df.groupby('class')['a'].apply(lambda x: x+1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     711             values,
# --> 712             not_indexed_same=mutated or self.mutated)
#     713
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _wrap_applied_output(self, keys, values, not_indexed_same)
#     891             return self._concat_objects(keys, values,
# --> 892                                         not_indexed_same=not_indexed_same)
#     893         elif isinstance(values[0], DataFrame):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _concat_objects(self, keys, values, not_indexed_same)
#     890             if isinstance(result, Series):
# --> 891                 result = result.reindex(ax)
#     892             else:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    3737     def reindex(self, index=None, **kwargs):
# -> 3738         return super(Series, self).reindex(index=index, **kwargs)
#    3739
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4368             new_index, indexer = ax.reindex(labels, level=level, limit=limit,
# -> 4369                                             tolerance=tolerance, method=method)
#    4370
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in reindex(self, target, method, level, limit, tolerance)
#    2226                 else:
# -> 2227                     raise ValueError("cannot handle a non-unique multi-index!")
#    2228
#
# ValueError: cannot handle a non-unique multi-index!
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-576cf8bf63c7> in <module>
# ----> 1 df.groupby('class')['a'].apply(lambda x: x+1)
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     747                       examples=_apply_docs['series_examples']))
#     748     def apply(self, func, *args, **kwargs):
# --> 749         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#     750
#     751     @Substitution(see_also=_agg_see_also_doc,
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     699
#     700                 with _group_selection_context(self):
# --> 701                     return self._python_apply_general(f)
#     702
#     703         return result
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     710             keys,
#     711             values,
# --> 712             not_indexed_same=mutated or self.mutated)
#     713
#     714     def _iterate_slices(self):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _wrap_applied_output(self, keys, values, not_indexed_same)
#     890         if isinstance(values[0], (Series, dict)):
#     891             return self._concat_objects(keys, values,
# --> 892                                         not_indexed_same=not_indexed_same)
#     893         elif isinstance(values[0], DataFrame):
#     894             # possible that Series -> DataFrame by applied function
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _concat_objects(self, keys, values, not_indexed_same)
#     889
#     890             if isinstance(result, Series):
# --> 891                 result = result.reindex(ax)
#     892             else:
#     893
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    3736     @Appender(generic.NDFrame.reindex.__doc__)
#    3737     def reindex(self, index=None, **kwargs):
# -> 3738         return super(Series, self).reindex(index=index, **kwargs)
#    3739
#    3740     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4367             ax = self._get_axis(a)
#    4368             new_index, indexer = ax.reindex(labels, level=level, limit=limit,
# -> 4369                                             tolerance=tolerance, method=method)
#    4370
#    4371             axis = self._get_axis_number(a)
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in reindex(self, target, method, level, limit, tolerance)
#    2225                                                tolerance=tolerance)
#    2226                 else:
# -> 2227                     raise ValueError("cannot handle a non-unique multi-index!")
#    2228
#    2229         if not isinstance(target, MultiIndex):
#
# ValueError: cannot handle a non-unique multi-index!
